# %%
Grid = ["-", "-", "-",
       "-", "-", "-",
       "-", "-", "-"]

# %%
# Function to print Noughts & Crosses game grid
def reveal_noughts_and_crosses_grid():
    print("\n")
    print('-------------------------------------------------------------')
    print('-------------------------------------------------------------')
    print("\tO|X   << THE GAME OF NOUGHTS & CROSSES >>   X|O")
    print('-------------------------------------------------------------')
    print("PLAYER 1: " + P1 + "\t\t\t\t\tPLAYER 2: " + P2)
    print("Team: " + S1 + "\t\t\t\t\t\tTeam: " + S2 )
    print("\n")
    print("\t\t          |        |")
    print("\t\t          |        |")
    print("\t\t       " + Grid[0] + "  |    " + Grid[1] + "   |   " +Grid[2])
    print("\t\t          |        |")
    print('\t\t  ________|________|________')
 
    print("\t\t          |        |")
    print("\t\t          |        |")
    print("\t\t       " + Grid[3] + "  |    " + Grid[4] + "   |   " +Grid[5])
    print("\t\t          |        |")
    print('\t\t  ________|________|________')
 
    print("\t\t          |        |")
    print("\t\t          |        |")
    print("\t\t       " + Grid[6] + "  |    " + Grid[7] + "   |   " +Grid[8])
    print("\t\t          |        |")
    print("\t\t          |        |")
    print("\n")
    print('-------------------------------------------------------------')
    print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
    print('-------------------------------------------------------------')
    print('-------------------------------------------------------------')
    print("\n")

# %%
reveal_noughts_and_crosses_grid()
# Out:
# -------------------------------------------------------------
# -------------------------------------------------------------
# 	O|X   << THE GAME OF NOUGHTS & CROSSES >>   X|O
# -------------------------------------------------------------
# PLAYER 1: JP					PLAYER 2: Lee
# Team: X						Team: O
#
#
# 		          |        |
# 		          |        |
# 		       -  |    -   |   -
# 		          |        |
# 		  ________|________|________
# 		          |        |
# 		          |        |
# 		       -  |    -   |   -
# 		          |        |
# 		  ________|________|________
# 		          |        |
# 		          |        |
# 		       -  |    -   |   -
# 		          |        |
# 		          |        |
#
#
# -------------------------------------------------------------
# XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX
# -------------------------------------------------------------
# -------------------------------------------------------------

# %% [markdown]
# # Project Day Action Plan:
#
#
# i)	List all ‘Noughts & Crosses’ Game Steps (How you chronologically manoeuvre through the virtual environment)
#
# ii)	Identify which functions/methods/variables/arguments are best suited to each step in (1.)
#
# iii)	List all ‘Noughts & Crosses’ Rules (Things you can and can’t do while playing)
#
# iv)	Identify which functions/methods/variables/arguments are best suited to each step in (3.)
#
# v)	List all virtual things to be displayed and are they possible to create in Jupyter?
#
# vi)	Identify which functions/methods/variables/arguments are best suited to each item in (5.) and chronologically where these fit into our actual game steps
#
#
#
# ### List all ‘Noughts & Crosses’ Game Steps:
#
# 1.	Start New Game (Do we need to have a ‘resume game’ or ‘continue game’ option also if we decide that there is also an option to pause/exit a game that’s already been started? Maybe a save game option? Is that possible?)
# -	Should this be a Yes/No or True/False scenario?
#
# 2.	Assign Player 1 & 2 (Are they called Player 1 & Player 2 by default, is there a way to allow you to rename so each player is custom? Eg. Player 1 = Jack, Player 2 = Jill)
#
# 3.	Assign ‘X’ and ‘0’ (should each symbol automatically be assigned to a player, or should this be a choice Player 1 can make for each new game?)
#
# 4.	Create & display a new game grid featuring 9 * empty squares in a 3x3 table format
# -	Create grid using ‘print(“strings”)’ with special characters
#
# 5.	Take 1st turn by Player 1 clicking on any of 9 empty boxes in the game grid
#
# 6.	Next Player 2 takes their 1st turn by Player 2 clicking on any of the 8 remaining empty boxes in the game grid
#
# 7.	Next Player 1 takes their 2nd turn by Player 1 clicking on any of the 7 remaining empty boxes left in the game grid
#
# 8.	Next Player 2 takes their 2nd turn by Player 2 clicking on any of the 6 remaining empty boxes in the game grid
#
# 9.	The process described in (4 – 7) above continues to loop itself (with one less empty square grid box per iteration/turn), until there are 0 empty squares remaining in the game grid
# -	While Loops repeat until a certain condition is met. Nested Loops
#
# 10.	Determine the final outcome of the game by satisfying one of following conditions:
#
# a)	If either player has 3 * ‘X’ or 3 * ‘Y’ symbols in a row, horizontally, vertically, or diagonally, on the game grid, then that player is classed as the winner (regardless of if there are still ‘y’ number of empty squares remaining on the game grid)
# b)	Or else if the condition of a) is not satisfied, and if there are 0 empty square spaces left in the game grid, then the game is immediately ended as a draw for both players
# -	Integrate a Break to stop the loop and declare a winner
#
# 11.	Display the final outcome as decided in (9) above. This may be some sort of text box/graphic displaying both the outcome and the player name. Examples include:
#
# -	‘WINNER: Player 1’ and ‘LOSER: Player 2’ both displayed
# -	‘WINNER: Player 1’ displayed only
# -	Note: If custom names then could look like ‘WINNER: Jack’ and ‘LOSER: Jill’ etc
# -	‘1st PLACE GOES TO: Jack’
# -	‘FIRST PLACE: Jack’
# -	‘And the WINNER is…  JACK!!!’
# -	‘JACK is the CHAMPION!!!’
# -	‘DRAW’
# -	‘Draw… Better luck next time!!!)
# -	‘DRAW: You’ve both met your match!’
#
# 12.	Cycle should now loop back to (1) by offering to ‘Start New Game’ (Should there also be a second option after a finished game allowing you to continue with the same players? This would also mean that the turn order and symbol would have to be reversed for the two players for the start of second game to make it fair)
#
#
#
# ### List all ‘Noughts & Crosses’ Rules:
#
# 1.	How many players can play at a time?
# -	Two Players
#
# 2.	How many turns can each player have at a time?
# -	1 Turn Each
#
# 3.	What is the turn order?
# -	Player 1, then Player 2, (repeat).
#
# 4.	What symbols can be used to represent a turn for each player?
# -	Placing either an ‘0’ (nought) or a ‘X’ (cross) in an empty square of the game grid
#
# 5.	How do you play a turn?
# -	Place either a ‘nought’ or a ‘cross’ inside an empty square on the game grid
#
# 6.	How do you win?
# -	3 * ‘noughts’ or 3 * ‘crosses’ in a row, whether horizontally, vertically, or diagonally, in the game grid
#
# 7.	How do you draw?
# -	If (6) is not satisfied/true
#
# 8.	When is the game over?
# -	Either when one of the players wins, or if nobody wins and the game is a draw (meaning there are no remaining empty squares left on the grid)
#
#
#
# ### List all virtual things to be displayed (and are they possible to create in Jupyter?):
#
# 1.	Display ‘Start Game’ Screen
#
# 2.	Display ‘Start Game/New Game’ Button/Box on ‘Start Game’ screen
#
# 3.	Next display ‘Player 1’ and ‘Player 2’ ‘Edit Name’ Boxes/Input/Screen
#
# 4.	Next display ‘Player 1 Choose Your Symbol’ Buttons/Boxes/Screen
#
# 5.	Next display the ‘Game grid or table’ featuring a total of 9 * empty squares (3*3) within game grid
#
# 6.	On same screen, display boxes at top of screen showing each player’s name and the symbol they have chosen or been assigned to for the entirety of the current game (eg. Name: Jill, Symbol: ‘0’, and, Name: Jack, Symbol: ‘X’)
#
# 7.	Display a box after each turn saying: ‘Next Player take your turn’ ???
#
# 8.	Display either a ‘0’ or an ‘X’ each time an empty square is clicked on, returned relative to which players’ turn it is (can we play with the design/font etc of our noughts and crosses)
#
# 9.	Finally display a ‘Final Outcome’ box/screen showing who won or drew based on the game result and related satisfying conditions
#
# 10.	Now we should loop back to (1) and display Start screen again
#
#
#
# ### List 5 Concepts you both used and intended to us:
#
# 1.	If/ Elif/ Else
#
# 2.	While Loops
#
# 3.	Input Method
#
# 4.	Creating and defining Functions
#
# 5.	Data Structures: Lists, Tuples, Sets, Dictionaries

# %%
#Function to determine Player 2's symbol, using if/elif formulae as below
def Team_2():  
    if S1 == "O":  
        return "X"  
    #If Player 1 chooses Noughts, then Player 2 must be Crosses
        
    elif S1 == "X":
        return "O"  
    #Or, if Player 1 chooses Crosses, then Player 2 must be Noughts

# %%
S2 = Team_2()  
#Here we are assigning the value of function Team_2, to text string S2, so we can add it in our string to create the game grid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 S2 = Team_2()
#
# Input In [3], in Team_2()
#       2 def Team_2():
# ----> 3     if S1 == "O":
#       4         return "X"
#       5     #If Player 1 chooses Noughts, then Player 2 must be Crosses
#
# NameError: name 'S1' is not defined

# %%
print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
print("\n")
N1 = input('\tWelcome To Noughts & Crosses!\n\nWould You Like To Start A New Game? (Yes or No): ')
#Input method gives players the option to start the game


if N1 == "Yes":
    print("\n")
    print('  New Game Commencing, May The Best Player Win!')
    print("\n")
    print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
    print("\n")
    #If Yes then the game starts
    
    P1 = input('Player 1, Enter Your Name: ')
    print("PLAYER 1's Name Is " + P1)
    print("\n")
    #Here the first player enters their name
    
    P2 = input('Player 2, Enter Your Name: ')
    print("PLAYER 2's Name Is " + P2)
    print("\n")
    #Here the second player enters their name
    
    S1 = input(P1 + ' , Do You Choose Noughts or Crosses? (O or X): ')
    #Players can input O or X to choose symbol
   
        
    if S1 == "O":
            print(P1 + " Chooses: O's")
            print("\n")   
            print(P2 + ", That Means You Are: X's")
            print("\n")
            print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
            #If Player 1 chooses O then Player 2 is X
            
            #Function to determine Player 2's symbol, using if/elif formulae as below
            def Team_2():  
                if S1 == "O":  
                    return "X"  
                #If Player 1 chooses Noughts, then Player 2 must be Crosses
                
            S2 = Team_2()  
            #Here we are assigning the function type to string type, so we can add it in our string calculation to create the grid
               
            reveal_noughts_and_crosses_grid()
            #Provided Player 1 chose an O or an X, this function will next display the main game grid
            
    elif S1 == "X":
            print(P1 + " Chooses: X's")
            print("\n")   
            print(P2 + ", That Means You Are: O's")
            print("\n")
            print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
            #If Player 1 chooses X then Player 2 is O
            
            #Function to determine Player 2's symbol, using if/elif formulae as below
            def Team_2():  
                if S1 == "X":  
                    return "O"  
                #If Player 1 chooses Noughts, then Player 2 must be Crosses
                
            S2 = Team_2()  
            #Here we are assigning the function type to string type, so we can add it in our string calculation to create the grid
            
        
            reveal_noughts_and_crosses_grid()
            #Provided Player 1 chose an O or an X, this function will next display the main game grid
            
    else:
        print("\n")
        print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
        print("\n")
        print("\t Only O or X Answers Please - Start Again!")
        print("\n")
        print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
        #If the player typed anything other than O or X, the game will end and they will be told to start again

elif N1 == "No":
    print("\n")
    print("\t Maybe Another Time Then, Goodbye!")
    print("\n")
    print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
    #If no then the game ends

else: 

    print("\n")
    print("\t Only Yes or No Answers Please - Start Again!")
    print("\n")
    print("XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX")
    #If the player typed anything other than Yes or No, the game will end and they will be told to start again
# Out:
# XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX
#
#
# 	Welcome To Noughts & Crosses!
#
# Would You Like To Start A New Game? (Yes or No): Yes
#
#
#   New Game Commencing, May The Best Player Win!
#
#
# XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX
#
#
# Player 1, Enter Your Name: Jay
# PLAYER 1's Name Is Jay
#
#
# Player 2, Enter Your Name: Kiel
# PLAYER 2's Name Is Kiel
#
#
# Jay , Do You Choose Noughts or Crosses? (O or X): X
# Jay Chooses: X's
#
#
# Kiel, That Means You Are: O's
#
#
# XOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOXOX
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#      63         S2 = Team_2()
#      64         #Here we are assigning the function type to string type, so we can add it in our string calculation to create the grid
# ---> 67         reveal_noughts_and_crosses_grid()
# ...

# %%
# Function to print Noughts & Crosses game grid
def print_noughts_and_crosses_grid(values):
    print("\n")
    print("\t     |     |")
    print("\t  {}  |  {}  |  {}".format(values[0], values[1], values[2]))
    print('\t_____|_____|_____')
 
    print("\t     |     |")
    print("\t  {}  |  {}  |  {}".format(values[3], values[4], values[5]))
    print('\t_____|_____|_____')
 
    print("\t     |     |")
 
    print("\t  {}  |  {}  |  {}".format(values[6], values[7], values[8]))
    print("\t     |     |")
    print("\n")

# %%
def display_board(board):
    print(board[7]+"|"+board[8]+"|"+board[9])
    print("-|-|-")
    print(board[4]+"|"+board[5]+"|"+board[6])
    print("-|-|-")
    print(board[1]+"|"+board[2]+"|"+board[3])
    print("-|-|-")
testing_board=[" "]*10
display_board(testing_board)
# Out:
#  | |
# -|-|-
#  | |
# -|-|-
#  | |
# -|-|-
